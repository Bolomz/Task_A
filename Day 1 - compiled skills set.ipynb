# %%
#Import all used modules

import numpy as np
import pandas as pd
import matplotlib as plt
from pandas import Series, DataFrame

# %%
#Read all .csv files to be considered.

As = pd.read_csv('Aishat_skills.csv')
Bs = pd.read_csv('Bisola_skills.csv')
Os = pd.read_csv('Feranmi_new_skills.csv')
Ss = pd.read_csv('Samuel_new_skills.csv')
Ts = pd.read_csv('Theo_new_skills.csv')
ABs = pd.read_csv('Abdul-baqqi_skills.csv')

# %%
#Viewing .csv file.

As
# Out:
#    Unnamed: 0       Skills
# 0           0       Python
# 1           1         HTML
# 2           2          CSS
# 3           3            C
# 4           4   Javascript
# 5           5         Java

# %%
#Renaming As.
df = As

#Changing column values.
df['Unnamed: 0'] = "Aishat"
df
# Out:
#   Unnamed: 0       Skills
# 0     Aishat       Python
# 1     Aishat         HTML
# 2     Aishat          CSS
# 3     Aishat            C
# 4     Aishat   Javascript
# 5     Aishat         Java

# %%
#Changing column names.
Skill_a = df[['Unnamed: 0', 'Skills']]
Skill_a.columns= ['Name', 'Skill Set']

#Output new data set.
Skill_a
# Out:
#      Name    Skill Set
# 0  Aishat       Python
# 1  Aishat         HTML
# 2  Aishat          CSS
# 3  Aishat            C
# 4  Aishat   Javascript
# 5  Aishat         Java

# %%
#Viewing .csv file.
Bs
# Out:
#    Unnamed: 0            Skills
# 0           0           AutoCAD
# 1           1            Python
# 2           2         Tailoring
# 3           3     Data Analysis
# 4           4           Writing
# 5           5       Power point
# 6           6    Microsoft Word
# 7           7   Microsoft Excel

# %%
#Changing variable name for file.
df_B = Bs

#Changing column values.
df_B['Unnamed: 0'] = "Bisola"

df_B
# Out:
#   Unnamed: 0            Skills
# 0     Bisola           AutoCAD
# 1     Bisola            Python
# 2     Bisola         Tailoring
# 3     Bisola     Data Analysis
# 4     Bisola           Writing
# 5     Bisola       Power point
# 6     Bisola    Microsoft Word
# 7     Bisola   Microsoft Excel

# %%
#Changing column names.
Skill_b = df_B[['Unnamed: 0', 'Skills']]
Skill_b.columns= ['Name', 'Skill Set']

#Output new data set.
Skill_b
# Out:
#      Name         Skill Set
# 0  Bisola           AutoCAD
# 1  Bisola            Python
# 2  Bisola         Tailoring
# 3  Bisola     Data Analysis
# 4  Bisola           Writing
# 5  Bisola       Power point
# 6  Bisola    Microsoft Word
# 7  Bisola   Microsoft Excel

# %%
#Viewing .csv file.
Os
# Out:
#    Unnamed: 0       Skills
# 0           0       Python
# 1           1         HTML
# 2           2          CSS
# 3           3            C
# 4           4   Javascript
# 5           5         Java

# %%
#Changing variable name for file.
df_O = Os

#Changing column values.
df_O['Unnamed: 0'] = "Oluwaferanmi"
df_O
# Out:
#      Unnamed: 0       Skills
# 0  Oluwaferanmi       Python
# 1  Oluwaferanmi         HTML
# 2  Oluwaferanmi          CSS
# 3  Oluwaferanmi            C
# 4  Oluwaferanmi   Javascript
# 5  Oluwaferanmi         Java

# %%
#Changing column names.
Skill_o = df_O[['Unnamed: 0', 'Skills']]
Skill_o.columns= ['Name', 'Skill Set']
Skill_o
# Out:
#            Name    Skill Set
# 0  Oluwaferanmi       Python
# 1  Oluwaferanmi         HTML
# 2  Oluwaferanmi          CSS
# 3  Oluwaferanmi            C
# 4  Oluwaferanmi   Javascript
# 5  Oluwaferanmi         Java

# %%
#Viewing .csv file.
Ss
# Out:
#    Unnamed: 0             Skills
# 0           0             Python
# 1           1   Machine learning
# 2           2             MATLAB
# 3           3     Microsoft Word
# 4           4    Microsoft Excel

# %%
#Changing variable name for file.
df_S = Ss

#Changing column values.
df_S['Unnamed: 0'] = "Samuel"
df_S
# Out:
#   Unnamed: 0             Skills
# 0     Samuel             Python
# 1     Samuel   Machine learning
# 2     Samuel             MATLAB
# 3     Samuel     Microsoft Word
# 4     Samuel    Microsoft Excel

# %%
#Changing column names.
Skill_s = df_S[['Unnamed: 0', 'Skills']]
Skill_s.columns= ['Name', 'Skill Set']

Skill_s
# Out:
#      Name          Skill Set
# 0  Samuel             Python
# 1  Samuel   Machine learning
# 2  Samuel             MATLAB
# 3  Samuel     Microsoft Word
# 4  Samuel    Microsoft Excel

# %%
#Viewing .csv file.
Ts
# Out:
#    Unnamed: 0             Skills
# 0           0             Python
# 1           1   Machine learning
# 2           2   Microsoft office

# %%
#Changing variable name for file.
df_t = pd.DataFrame(Ts)

#Changing column values.
df_t['Unnamed: 0'] = "Theophilus"
df_t
# Out:
#    Unnamed: 0             Skills
# 0  Theophilus             Python
# 1  Theophilus   Machine learning
# 2  Theophilus   Microsoft office

# %%
#Changing column names.
Skill_t = df_t[['Unnamed: 0', 'Skills']]
Skill_t.columns= ['Name', 'Skill Set']

Skill_t
# Out:
#          Name          Skill Set
# 0  Theophilus             Python
# 1  Theophilus   Machine learning
# 2  Theophilus   Microsoft office

# %%
#Viewing .csv file.
ABs
# Out:
#    Unnamed: 0            Skills
# 0           0            Python
# 1           1   Graphics Design
# 2           2   video animation
# 3           3      video editor

# %%
#Changing variable name for file.
df_ab = pd.DataFrame(ABs)

#Changing column values.
df_ab['Unnamed: 0'] = "Abdulbaqqi"
df_ab['Skill set'] = df_ab['Skills']

# %%
#Changing column names.
Skill_ab = df_ab[['Unnamed: 0', 'Skills']]
Skill_ab.columns= ['Name', 'Skill Set']

Skill_ab
# Out:
#          Name         Skill Set
# 0  Abdulbaqqi            Python
# 1  Abdulbaqqi   Graphics Design
# 2  Abdulbaqqi   video animation
# 3  Abdulbaqqi      video editor

# %%
#Joining all skills data sets into a single table.

Skill_set = pd.concat([Skill_a, Skill_ab, Skill_b, Skill_o, Skill_s, Skill_t])

#Print value.
Skill_set
# Out:
#            Name          Skill Set
# 0        Aishat             Python
# 1        Aishat               HTML
# 2        Aishat                CSS
# 3        Aishat                  C
# 4        Aishat         Javascript
# 5        Aishat               Java
# 0    Abdulbaqqi             Python
# 1    Abdulbaqqi    Graphics Design
# 2    Abdulbaqqi    video animation
# 3    Abdulbaqqi       video editor
# 0        Bisola            AutoCAD
# 1        Bisola             Python
# 2        Bisola          Tailoring
# 3        Bisola      Data Analysis
# 4        Bisola            Writing
# 5        Bisola        Power point
# 6        Bisola     Microsoft Word
# 7        Bisola    Microsoft Excel
# 0  Oluwaferanmi             Python
# 1  Oluwaferanmi               HTML
# 2  Oluwaferanmi                CSS
# 3  Oluwaferanmi                  C
# 4  Oluwaferanmi         Javascript
# 5  Oluwaferanmi               Java
# 0        Samuel             Python
# 1        Samuel   Machine learning
# ...

# %%
#Save as csv file.
Skill_set.to_csv('Skill_set.csv', encoding='utf-8')
Skillset= pd.read_csv('Skill_set.csv')

# %%
#Dropping column, Unnamed: 0.
skill_sets = Skillset.drop(['Unnamed: 0'], axis=1)
skill_sets
# Out:
#             Name          Skill Set
# 0         Aishat             Python
# 1         Aishat               HTML
# 2         Aishat                CSS
# 3         Aishat                  C
# 4         Aishat         Javascript
# 5         Aishat               Java
# 6     Abdulbaqqi             Python
# 7     Abdulbaqqi    Graphics Design
# 8     Abdulbaqqi    video animation
# 9     Abdulbaqqi       video editor
# 10        Bisola            AutoCAD
# 11        Bisola             Python
# 12        Bisola          Tailoring
# 13        Bisola      Data Analysis
# 14        Bisola            Writing
# 15        Bisola        Power point
# 16        Bisola     Microsoft Word
# 17        Bisola    Microsoft Excel
# 18  Oluwaferanmi             Python
# 19  Oluwaferanmi               HTML
# 20  Oluwaferanmi                CSS
# 21  Oluwaferanmi                  C
# 22  Oluwaferanmi         Javascript
# 23  Oluwaferanmi               Java
# 24        Samuel             Python
# ...

# %%
#Save as csv file.
skill_sets.to_csv('Skill_Sets.csv', encoding='utf-8')
